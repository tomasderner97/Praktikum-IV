# %%
from fit_errors import *

# %%
# %load_ext autoreload
# %autoreload 2

# %%
_, _, fit = plot_fit_errors()

# %%
fit.params
# Out:
# array([3.76172169])

# %%
fit.errors
# Out:
# [0.585565174846159]

# %%
from uncertainties import ufloat
print(ufloat(fit.params[0], fit.errors[0]))
# Out:
# 3.8+/-0.6
