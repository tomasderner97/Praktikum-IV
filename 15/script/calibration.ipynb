# %%
from calibration import *

# %%
# %load_ext autoreload
# %autoreload 2

# %%
dataframe_from_csv("../data/calibration_params.csv")
# Out:
#   param         value         error
# 0     a  5.360930e-15  9.337000e-16
# 1     b -4.810100e-11  1.038000e-11
# 2     c  1.795190e-07  4.466000e-08
# 3     d -3.182380e-04  9.245000e-05
# 4     e  3.183160e-01  9.153000e-02
# 5     f  2.660500e+02  3.448000e+01

# %%
plot_calibration()
# Out:
# ---------------------------------------------------------------------------
# ParseFatalException                       Traceback (most recent call last)
# ~\Miniconda3\lib\site-packages\matplotlib\mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2597         try:
# -> 2598             result = self._expression.parseString(s)
#    2599         except ParseBaseException as err:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1944                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1945                 raise exc
#    1946         else:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1934         try:
# -> 1935             loc, tokens = self._parse(instring, 0)
#    1936             if parseAll:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4442         if self.expr is not None:
# -> 4443             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4444         else:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4049             else:
# -> 4050                 loc, exprtokens = e._parse(instring, loc, doActions)
#    4051             if exprtokens or exprtokens.haskeys():
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4761         try:
# -> 4762             return super(ZeroOrMore, self).parseImpl(instring, loc, doActions)
#    4763         except (ParseException, IndexError):
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4677             try_not_ender(instring, loc)
# -> 4678         loc, tokens = self_expr_parse(instring, loc, doActions, callPreParse=False)
#    4679         try:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4032         # pre-parsed the string as part of our And pre-parsing
# -> 4033         loc, resultlist = self.exprs[0]._parse(instring, loc, doActions, callPreParse=False)
#    4034         errorStop = False
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1707                     try:
# -> 1708                         tokens = fn(instring, tokensStart, retTokens)
#    1709                     except IndexError as parse_action_exc:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in wrapper(*args)
#    1313             try:
# -> 1314                 ret = func(*args[limit[0]:])
#    1315                 foundArity[0] = True
#
# ~\Miniconda3\lib\site-packages\matplotlib\mathtext.py in math_string(self, s, loc, toks)
#    2672     def math_string(self, s, loc, toks):
# -> 2673         return self._math_expression.parseString(toks[0][1:-1])
#    2674
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1944                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1945                 raise exc
#    1946         else:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1934         try:
# -> 1935             loc, tokens = self._parse(instring, 0)
#    1936             if parseAll:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4442         if self.expr is not None:
# -> 4443             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4444         else:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4687                     preloc = loc
# -> 4688                 loc, tmptokens = self_expr_parse(instring, preloc, doActions)
#    4689                 if tmptokens or tmptokens.haskeys():
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4442         if self.expr is not None:
# -> 4443             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4444         else:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4234             try:
# -> 4235                 ret = e._parse(instring, loc, doActions)
#    4236                 return ret
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1707                     try:
# -> 1708                         tokens = fn(instring, tokensStart, retTokens)
#    1709                     except IndexError as parse_action_exc:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in wrapper(*args)
#    1313             try:
# -> 1314                 ret = func(*args[limit[0]:])
#    1315                 foundArity[0] = True
#
# ~\Miniconda3\lib\site-packages\matplotlib\mathtext.py in unknown_symbol(self, s, loc, toks)
#    2767         c = toks[0]
# -> 2768         raise ParseFatalException(s, loc, "Unknown symbol: %s" % c)
#    2769
#
# ParseFatalException: Unknown symbol: \si, found '\'  (at char 7), (line:1, col:8)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-a4f52cd7e608> in <module>
# ----> 1 plot_calibration()
#
# ~\Repositories\praktikum-iv\15\script\calibration.py in plot_calibration(name)
#      27     ax.legend()
#      28
# ---> 29     fig.tight_layout()
#      30
#      31     fig.savefig(f"../plot/{name or 'plot'}.pdf")
#
# ~\Miniconda3\lib\site-packages\matplotlib\figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2474         kwargs = get_tight_layout_figure(
#    2475             self, self.axes, subplotspec_list, renderer,
# -> 2476             pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    2477         if kwargs:
#    2478             self.subplots_adjust(**kwargs)
#
# ~\Miniconda3\lib\site-packages\matplotlib\tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     360                                      subplot_list=subplot_list,
#     361                                      ax_bbox_list=ax_bbox_list,
# --> 362                                      pad=pad, h_pad=h_pad, w_pad=w_pad)
#     363
#     364     # kwargs can be none if tight_layout fails...
#
# ~\Miniconda3\lib\site-packages\matplotlib\tight_layout.py in auto_adjust_subplotpars(fig, renderer, nrows_ncols, num1num2_list, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#     109             continue
#     110
# --> 111         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
#     112                                 if ax.get_visible()])
#     113         tight_bbox = TransformedBbox(tight_bbox_raw,
#
# ~\Miniconda3\lib\site-packages\matplotlib\tight_layout.py in <listcomp>(.0)
#     110
#     111         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
# --> 112                                 if ax.get_visible()])
#     113         tight_bbox = TransformedBbox(tight_bbox_raw,
#     114                                      fig.transFigure.inverted())
#
# ~\Miniconda3\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4357                 bb.append(bb_xaxis)
#    4358
# -> 4359             bb_yaxis = self.yaxis.get_tightbbox(renderer)
#    4360             if bb_yaxis:
#    4361                 bb.append(bb_yaxis)
#
# ~\Miniconda3\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer)
#    1176               if a.get_visible()),
#    1177             *ticklabelBoxes,
# -> 1178             *ticklabelBoxes2,
#    1179         ]
#    1180         bboxes = [b for b in bboxes
#
# ~\Miniconda3\lib\site-packages\matplotlib\axis.py in <genexpr>(.0)
#    1174             *(a.get_window_extent(renderer)
#    1175               for a in [self.label, self.offsetText]
# -> 1176               if a.get_visible()),
#    1177             *ticklabelBoxes,
#    1178             *ticklabelBoxes2,
#
# ~\Miniconda3\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     888             raise RuntimeError('Cannot get window extent w/o renderer')
#     889
# --> 890         bbox, info, descent = self._get_layout(self._renderer)
#     891         x, y = self.get_unitless_position()
#     892         x, y = self.get_transform().transform_point((x, y))
#
# ~\Miniconda3\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     296             if clean_line:
#     297                 w, h, d = renderer.get_text_width_height_descent(
# --> 298                     clean_line, self._fontproperties, ismath=ismath)
#     299             else:
#     300                 w = h = d = 0
#
# ~\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     204         if ismath:
#     205             ox, oy, width, height, descent, fonts, used_characters = \
# --> 206                 self.mathtext_parser.parse(s, self.dpi, prop)
#     207             return width, height, descent
#     208
#
# ~\Miniconda3\lib\site-packages\matplotlib\mathtext.py in parse(self, s, dpi, prop)
#    3369             self.__class__._parser = Parser()
#    3370
# -> 3371         box = self._parser.parse(s, font_output, fontsize, dpi)
#    3372         font_output.set_canvas_size(box.width, box.height, box.depth)
#    3373         return font_output.get_results(box)
#
# ~\Miniconda3\lib\site-packages\matplotlib\mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2601                                         err.line,
#    2602                                         " " * (err.column - 1) + "^",
# -> 2603                                         str(err)]))
#    2604         self._state_stack = None
#    2605         self._em_width_cache = {}
#
# ValueError:
# \lambda\si{nm}
#        ^
# Unknown symbol: \si, found '\'  (at char 7), (line:1, col:8)
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x000001FD9D159378> (for post_execute):
# ---------------------------------------------------------------------------
# ParseFatalException                       Traceback (most recent call last)
# ~\Miniconda3\lib\site-packages\matplotlib\mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2597         try:
# -> 2598             result = self._expression.parseString(s)
#    2599         except ParseBaseException as err:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1944                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1945                 raise exc
#    1946         else:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1934         try:
# -> 1935             loc, tokens = self._parse(instring, 0)
#    1936             if parseAll:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4442         if self.expr is not None:
# -> 4443             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4444         else:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4049             else:
# -> 4050                 loc, exprtokens = e._parse(instring, loc, doActions)
#    4051             if exprtokens or exprtokens.haskeys():
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4761         try:
# -> 4762             return super(ZeroOrMore, self).parseImpl(instring, loc, doActions)
#    4763         except (ParseException, IndexError):
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4677             try_not_ender(instring, loc)
# -> 4678         loc, tokens = self_expr_parse(instring, loc, doActions, callPreParse=False)
#    4679         try:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4032         # pre-parsed the string as part of our And pre-parsing
# -> 4033         loc, resultlist = self.exprs[0]._parse(instring, loc, doActions, callPreParse=False)
#    4034         errorStop = False
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1707                     try:
# -> 1708                         tokens = fn(instring, tokensStart, retTokens)
#    1709                     except IndexError as parse_action_exc:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in wrapper(*args)
#    1313             try:
# -> 1314                 ret = func(*args[limit[0]:])
#    1315                 foundArity[0] = True
#
# ~\Miniconda3\lib\site-packages\matplotlib\mathtext.py in math_string(self, s, loc, toks)
#    2672     def math_string(self, s, loc, toks):
# -> 2673         return self._math_expression.parseString(toks[0][1:-1])
#    2674
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1944                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1945                 raise exc
#    1946         else:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1934         try:
# -> 1935             loc, tokens = self._parse(instring, 0)
#    1936             if parseAll:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4442         if self.expr is not None:
# -> 4443             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4444         else:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4687                     preloc = loc
# -> 4688                 loc, tmptokens = self_expr_parse(instring, preloc, doActions)
#    4689                 if tmptokens or tmptokens.haskeys():
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4442         if self.expr is not None:
# -> 4443             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4444         else:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4234             try:
# -> 4235                 ret = e._parse(instring, loc, doActions)
#    4236                 return ret
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1707                     try:
# -> 1708                         tokens = fn(instring, tokensStart, retTokens)
#    1709                     except IndexError as parse_action_exc:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in wrapper(*args)
#    1313             try:
# -> 1314                 ret = func(*args[limit[0]:])
#    1315                 foundArity[0] = True
#
# ~\Miniconda3\lib\site-packages\matplotlib\mathtext.py in unknown_symbol(self, s, loc, toks)
#    2767         c = toks[0]
# -> 2768         raise ParseFatalException(s, loc, "Unknown symbol: %s" % c)
#    2769
#
# ParseFatalException: Unknown symbol: \si, found '\'  (at char 7), (line:1, col:8)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\Miniconda3\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# ~\Miniconda3\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# ~\Miniconda3\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    1905         if not self._is_idle_drawing:
#    1906             with self._idle_draw_cntx():
# -> 1907                 self.draw(*args, **kwargs)
#    1908
#    1909     def draw_cursor(self, event):
#
# ~\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~\Miniconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Miniconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~\Miniconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~\Miniconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Miniconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# ~\Miniconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~\Miniconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Miniconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1215         self._update_label_position(renderer)
#    1216
# -> 1217         self.label.draw(renderer)
#    1218
#    1219         self._update_offset_text_position(ticklabelBoxes, ticklabelBoxes2)
#
# ~\Miniconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Miniconda3\lib\site-packages\matplotlib\text.py in draw(self, renderer)
#     668
#     669         with _wrap_text(self) as textobj:
# --> 670             bbox, info, descent = textobj._get_layout(renderer)
#     671             trans = textobj.get_transform()
#     672
#
# ~\Miniconda3\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     296             if clean_line:
#     297                 w, h, d = renderer.get_text_width_height_descent(
# --> 298                     clean_line, self._fontproperties, ismath=ismath)
#     299             else:
#     300                 w = h = d = 0
#
# ~\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     204         if ismath:
#     205             ox, oy, width, height, descent, fonts, used_characters = \
# --> 206                 self.mathtext_parser.parse(s, self.dpi, prop)
#     207             return width, height, descent
#     208
#
# ~\Miniconda3\lib\site-packages\matplotlib\mathtext.py in parse(self, s, dpi, prop)
#    3369             self.__class__._parser = Parser()
#    3370
# -> 3371         box = self._parser.parse(s, font_output, fontsize, dpi)
#    3372         font_output.set_canvas_size(box.width, box.height, box.depth)
#    3373         return font_output.get_results(box)
#
# ~\Miniconda3\lib\site-packages\matplotlib\mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2601                                         err.line,
#    2602                                         " " * (err.column - 1) + "^",
# -> 2603                                         str(err)]))
#    2604         self._state_stack = None
#    2605         self._em_width_cache = {}
#
# ValueError:
# \lambda\si{nm}
#        ^
# Unknown symbol: \si, found '\'  (at char 7), (line:1, col:8)
# ---------------------------------------------------------------------------
# ParseFatalException                       Traceback (most recent call last)
# ~\Miniconda3\lib\site-packages\matplotlib\mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2597         try:
# -> 2598             result = self._expression.parseString(s)
#    2599         except ParseBaseException as err:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1944                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1945                 raise exc
#    1946         else:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1934         try:
# -> 1935             loc, tokens = self._parse(instring, 0)
#    1936             if parseAll:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4442         if self.expr is not None:
# -> 4443             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4444         else:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4049             else:
# -> 4050                 loc, exprtokens = e._parse(instring, loc, doActions)
#    4051             if exprtokens or exprtokens.haskeys():
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4761         try:
# -> 4762             return super(ZeroOrMore, self).parseImpl(instring, loc, doActions)
#    4763         except (ParseException, IndexError):
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4677             try_not_ender(instring, loc)
# -> 4678         loc, tokens = self_expr_parse(instring, loc, doActions, callPreParse=False)
#    4679         try:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4032         # pre-parsed the string as part of our And pre-parsing
# -> 4033         loc, resultlist = self.exprs[0]._parse(instring, loc, doActions, callPreParse=False)
#    4034         errorStop = False
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1707                     try:
# -> 1708                         tokens = fn(instring, tokensStart, retTokens)
#    1709                     except IndexError as parse_action_exc:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in wrapper(*args)
#    1313             try:
# -> 1314                 ret = func(*args[limit[0]:])
#    1315                 foundArity[0] = True
#
# ~\Miniconda3\lib\site-packages\matplotlib\mathtext.py in math_string(self, s, loc, toks)
#    2672     def math_string(self, s, loc, toks):
# -> 2673         return self._math_expression.parseString(toks[0][1:-1])
#    2674
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1944                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1945                 raise exc
#    1946         else:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseString(self, instring, parseAll)
#    1934         try:
# -> 1935             loc, tokens = self._parse(instring, 0)
#    1936             if parseAll:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4442         if self.expr is not None:
# -> 4443             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4444         else:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4687                     preloc = loc
# -> 4688                 loc, tmptokens = self_expr_parse(instring, preloc, doActions)
#    4689                 if tmptokens or tmptokens.haskeys():
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4442         if self.expr is not None:
# -> 4443             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4444         else:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1674                 try:
# -> 1675                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1676                 except IndexError:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4234             try:
# -> 4235                 ret = e._parse(instring, loc, doActions)
#    4236                 return ret
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1835                 try:
# -> 1836                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1837                 except ParseBaseException as pe:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1707                     try:
# -> 1708                         tokens = fn(instring, tokensStart, retTokens)
#    1709                     except IndexError as parse_action_exc:
#
# ~\Miniconda3\lib\site-packages\pyparsing.py in wrapper(*args)
#    1313             try:
# -> 1314                 ret = func(*args[limit[0]:])
#    1315                 foundArity[0] = True
#
# ~\Miniconda3\lib\site-packages\matplotlib\mathtext.py in unknown_symbol(self, s, loc, toks)
#    2767         c = toks[0]
# -> 2768         raise ParseFatalException(s, loc, "Unknown symbol: %s" % c)
#    2769
#
# ParseFatalException: Unknown symbol: \si, found '\'  (at char 7), (line:1, col:8)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\Miniconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\Miniconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\Miniconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~\Miniconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2054                         orientation=orientation,
#    2055                         dryrun=True,
# -> 2056                         **kwargs)
#    2057                     renderer = self.figure._cachedRenderer
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# ~\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# ~\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~\Miniconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Miniconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~\Miniconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~\Miniconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Miniconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# ~\Miniconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~\Miniconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Miniconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1215         self._update_label_position(renderer)
#    1216
# -> 1217         self.label.draw(renderer)
#    1218
#    1219         self._update_offset_text_position(ticklabelBoxes, ticklabelBoxes2)
#
# ~\Miniconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Miniconda3\lib\site-packages\matplotlib\text.py in draw(self, renderer)
#     668
#     669         with _wrap_text(self) as textobj:
# --> 670             bbox, info, descent = textobj._get_layout(renderer)
#     671             trans = textobj.get_transform()
#     672
#
# ~\Miniconda3\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     296             if clean_line:
#     297                 w, h, d = renderer.get_text_width_height_descent(
# --> 298                     clean_line, self._fontproperties, ismath=ismath)
#     299             else:
#     300                 w = h = d = 0
#
# ~\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     204         if ismath:
#     205             ox, oy, width, height, descent, fonts, used_characters = \
# --> 206                 self.mathtext_parser.parse(s, self.dpi, prop)
#     207             return width, height, descent
#     208
#
# ~\Miniconda3\lib\site-packages\matplotlib\mathtext.py in parse(self, s, dpi, prop)
#    3369             self.__class__._parser = Parser()
#    3370
# -> 3371         box = self._parser.parse(s, font_output, fontsize, dpi)
#    3372         font_output.set_canvas_size(box.width, box.height, box.depth)
#    3373         return font_output.get_results(box)
#
# ~\Miniconda3\lib\site-packages\matplotlib\mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2601                                         err.line,
#    2602                                         " " * (err.column - 1) + "^",
# -> 2603                                         str(err)]))
#    2604         self._state_stack = None
#    2605         self._em_width_cache = {}
#
# ValueError:
# \lambda\si{nm}
#        ^
# Unknown symbol: \si, found '\'  (at char 7), (line:1, col:8)

# %%
import matplotlib as mpl; print(mpl.font_manager.get_cachedir())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-fd0b0f3ba654> in <module>
# ----> 1 import matplotlib as mpl; print(mpl.font_manager.get_cachedir())
#
# AttributeError: module 'matplotlib.font_manager' has no attribute 'get_cachedir'
