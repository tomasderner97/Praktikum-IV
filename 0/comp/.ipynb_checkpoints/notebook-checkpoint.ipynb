# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.dpi"] = 100

# %%
# %run main.py
plt.rcParams["figure.dpi"]

# %%
df.describe()
# Out:
#                  E           ra           cs           na
# count  8192.000000  8192.000000  8192.000000  8192.000000
# mean   1834.406502    85.101562    55.121460    70.741211
# std    1059.485926   279.936853   194.524006   130.378083
# min      -0.049554     0.000000     0.000000     0.000000
# 25%     916.996312     0.000000     0.000000     3.000000
# 50%    1834.260751     6.000000     1.000000    25.000000
# 75%    2751.743763    53.000000    14.000000    83.000000
# max    3669.445347  7381.000000  7588.000000  2332.000000

# %%
plt.plot(df.E, df.ra)
plt.plot(df.E, df.cs)
plt.plot(df.E, df.na)
plt.yscale("log")
