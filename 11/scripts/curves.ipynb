# %%
from curves import *

# %%
# %load_ext autoreload
# %autoreload 2

# %%
df = get_proud_0A()

# %%
df
# Out:
#            sys_time  delta_time         x         y
# 0      3.783408e+09       0.109  0.008874  0.308368
# 1      3.783408e+09       0.218  0.006939  0.305690
# 2      3.783408e+09       0.328  0.007426  0.303955
# 3      3.783408e+09       0.437  0.007053  0.302192
# 4      3.783408e+09       0.547  0.007765  0.302870
# ...             ...         ...       ...       ...
# 11589  3.783409e+09    1268.250  0.778063  0.342882
# 11590  3.783409e+09    1268.359  0.778639  0.341933
# 11591  3.783409e+09    1268.468  0.778616  0.343082
# 11592  3.783409e+09    1268.578  0.779385  0.343153
# 11593  3.783409e+09    1268.687  0.779656  0.343018
#
# [11594 rows x 4 columns]

# %%
plot_proud(df)
# Out:
# (<Figure size 900x562.5 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1d2789c9b88>)

# %%
plot_fit_0A()

# %%
plot_proud()
# Out:
# (<Figure size 900x900 with 6 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001D2028B33C8>,
# ...
#        dtype=object))
