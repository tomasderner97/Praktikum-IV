# %%
from curves import *

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
plot_fit_0A()

# %%
plot_proud()
# Out:
# (<Figure size 900x900 with 6 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001CFC2B10248>,
# ...
#        dtype=object))
