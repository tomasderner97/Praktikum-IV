# %%
from spread import *

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = get_spread()

# %%
df["dx"] = df["dU"] * 21.2

# %%
df
# Out:
#       I     B     dU      dx         q    grad_B
# 0  0.00  0.00  0.000  0.0000      -inf  0.000000
# 1  0.26  0.18  0.073  1.5476  1.616888  0.069696
# 2  0.38  0.28  0.089  1.8868  2.252342  0.108416
# 3  0.51  0.39  0.109  2.3108  2.994371  0.151008
# 4  0.77  0.57  0.148  3.1376  4.358904  0.220704
# 5  0.98  0.67  0.176  3.7312  5.304588  0.259424

# %%
_, _, fit = plot_fit()

# %%
fit.params
# Out:
# array([0.04933539])

# %%
fit.errors
# Out:
# [0.0007837343787545801]

# %%
from uncertainties import ufloat
k = ufloat(fit.params[0], fit.errors[0])

# %%
from scipy.constants import Boltzmann

# %%
Boltzmann
# Out:
# 1.38064852e-23

# %%
L = ufloat(70, 1)
l = ufloat(700, 10)
T = ufloat(273 + 170, 5)

# %%
mu_b = 2 * Boltzmann * T / (l*L*(1 - L / (2 * l))) * k

# %%
print(mu_b)
# Out:
# (1.30+/-0.04)e-20

# %%
# Out:
# 49335.39265000827+/-783.7343787545801
